# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from scipy import stats

# %%
os.chdir ("D:/My Work/Sem-3/DAI-101/Assignment 1")

# %%
df = pd.read_csv('zomato.csv')

# %%
print (df.shape)
# Out:
# (51717, 17)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.tail()
# Out:
#                                                      url  \
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
df.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df.drop(['address','menu_item','url','dish_liked','phone','reviews_list','cuisines'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                     name online_order book_table   rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1/5    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1/5    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8/5    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88  Banashankari
# 4          Grand Village           No         No  3.8/5    166  Basavanagudi
#
#              rest_type approx_cost(for two people) listed_in(type)  \
# 0        Casual Dining                         800          Buffet
# 1        Casual Dining                         800          Buffet
# 2  Cafe, Casual Dining                         800          Buffet
# 3          Quick Bites                         300          Buffet
# 4        Casual Dining                         600          Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari
# 2    Banashankari
# 3    Banashankari
# ...

# %%
#Converting object datatypes into int and float for further analysis

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '4.6/5', '4.0/5', '4.2/5', '3.9/5',
#        '3.0/5', '3.6/5', '2.8/5', '4.4/5', '3.1/5', '4.3/5', '2.6/5',
#        '3.3/5', '3.5/5', '3.8 /5', '3.2/5', '4.5/5', '2.5/5', '2.9/5',
#        '3.4/5', '2.7/5', '4.7/5', 'NEW', '2.4/5', '2.2/5', '2.3/5',
#        '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5', '2.9 /5',
#        '2.7 /5', '2.5 /5', '2.6 /5', '4.5 /5', '4.3 /5', '3.7 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '3.4 /5', '3.6 /5',
#        '3.3 /5', '4.6 /5', '4.9 /5', '3.2 /5', '3.0 /5', '2.8 /5',
#        '3.5 /5', '3.1 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
def handlerate(value):
    if value == 'NEW' or value == '-':
        return np.nan
    else:
        value = str(value).split('/')
        value = value[0]
        return float(value)

# %%
df['rate'] = df['rate'].apply(handlerate)
df['rate'].head()
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: float64

# %%
df['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '750', '200', '850', '1,200', '150', '350', '250', '1,500',
#        '1,300', '1,000', '100', '900', '1,100', '1,600', '950', '230',
#        '1,700', '1,400', '1,350', '2,200', '2,000', '1,800', '1,900',
#        '180', '330', '2,500', '2,100', '3,000', '2,800', '3,400', '40',
#        '1,250', '3,500', '4,000', '2,400', '1,450', '3,200', '6,000',
#        '1,050', '4,100', '2,300', '120', '2,600', '5,000', '3,700',
#        '1,650', '2,700', '4,500'], dtype=object)

# %%
def removecomma(value):
    value = str(value)
    
    if ',' in value:
        value = value.replace(',', '')
        return float(value)
    else:
        return float(value)

df['approx_cost(for two people)'] = df['approx_cost(for two people)'].apply(removecomma)

# %%
df.dtypes
# Out:
# name                            object
# online_order                    object
# book_table                      object
# rate                           float64
# votes                            int64
# location                        object
# rest_type                       object
# approx_cost(for two people)    float64
# listed_in(type)                 object
# listed_in(city)                 object
# dtype: object

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %% [markdown]
# #### Categorical

# %%
df['online_order'].value_counts().plot(kind="pie",autopct="%1.2f%%")
plt.title('Online Order')
# Out:
# Text(0.5, 1.0, 'Online Order')

# %%
df['online_order'].value_counts().plot(kind="bar")
plt.title('online order distribution')
# Out:
# Text(0.5, 1.0, 'online order distribution')

# %%
df['book_table'].value_counts()
# Out:
# book_table
# No     17071
# Yes     6122
# Name: count, dtype: int64

# %%
df['book_table'].value_counts().plot(kind="bar")
plt.title('Table Bookings')
# Out:
# Text(0.5, 1.0, 'Table Bookings')

# %% [markdown]
# #### Numerical

# %%
column = 'approx_cost(for two people)'

# Box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df[column].dropna())
plt.show()

# %%
sns.distplot(df['rate'])
plt.title('Distribution of rating')
# Out:
# C:\Users\riyab\AppData\Local\Temp\ipykernel_3448\591839228.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['rate'])
# Text(0.5, 1.0, 'Distribution of rating')

# %%
#By the distribution graph of Rating, we can find that the ratings are not normally distributed and the distribution is left skewed.
df['rate'].skew()
# Out:
# -1.225313022256614

# %%
sns.distplot(df['approx_cost(for two people)'])
plt.title('Distribution of cost')
# Out:
# C:\Users\riyab\AppData\Local\Temp\ipykernel_3448\513793854.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['approx_cost(for two people)'])
# Text(0.5, 1.0, 'Distribution of cost')

# %%
#By the distribution graph of Rating, we can find that the ratings are not normally distributed and the distribution is right skewed.
df['approx_cost(for two people)'].skew()
# Out:
# 2.0187719053496536

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %% [markdown]
# #### Numerical and Numerical

# %%
sns.scatterplot(data = df,x="rate",y="approx_cost(for two people)")
# Out:
# <Axes: xlabel='rate', ylabel='approx_cost(for two people)'>

# %%
#by scatter plot, we can see that there is not a linear relationship between the cost of food and the ratings that the people give.
#Thus people judge the food by the quality of service and not the rate of food.

# %%
df.groupby(by='rate')['approx_cost(for two people)'].mean().plot.bar()
# Out:
# <Axes: xlabel='rate'>

# %% [markdown]
# #### Categorical and Numerical

# %%
sns.barplot(data=df,x="listed_in(type)", y="rate")
plt.title('Restraunt type which gets the highest rating')
plt.xticks(rotation=80)
plt.show()

# %%
#This graph shows that the rating of Pubs and Bars is the highest

# %%
sns.barplot(data=df,x="listed_in(city)", y="rate")
plt.title('Which city gives the highest rating')
plt.xticks(rotation=80)
plt.show()

# %%
#The plot shows that the restraunt recieves almost equal ratings from all the cities, i.e. the restraunt is performing equally good in all th cities in terms of its food and staff engagements.

# %%
sns.barplot(data=df,x="listed_in(city)", y="approx_cost(for two people)")
plt.title('Which city creates the highest revenue')
plt.xticks(rotation=80)
plt.show()

# %%
#This plot shows that there are a few cities where the restraunt generates more revenue than the others. So, it would be benificial if more outlets are setup in those cities.

# %% [markdown]
# #### categorical and categorical

# %%
pd.crosstab(df['online_order'],df['listed_in(type)'])
# Out:
# listed_in(type)  Buffet  Cafes  Delivery  Desserts  Dine-out  \
# online_order
# No                  425    366      1410       447      3171
# Yes                 337    681      9215       886      4838
#
# listed_in(type)  Drinks & nightlife  Pubs and bars
# online_order
# No                              663            353
# Yes                             227            174

# %%
sns.heatmap(pd.crosstab(df['online_order'],df['listed_in(type)']))
# Out:
# <Axes: xlabel='listed_in(type)', ylabel='online_order'>

# %%
pd.crosstab(df['listed_in(type)'],df['listed_in(city)'])
# Out:
# listed_in(city)     BTM  Banashankari  Bannerghatta Road  Basavanagudi  \
# listed_in(type)
# Buffet               36             6                 13            13
# Cafes                64            17                 21            32
# Delivery            729           210                292           301
# Desserts             80            13                 25            39
# Dine-out            439           121                181           202
# Drinks & nightlife   36             5                 15            10
# Pubs and bars        39             0                  0             0
#
# listed_in(city)     Bellandur  Brigade Road  Brookefield  Church Street  \
# listed_in(type)
# Buffet                     28            48           24             50
# Cafes                      11            46           17             52
# Delivery                  257           346          324            322
# Desserts                   22            55           18             56
# ...

# %%
sns.heatmap(pd.crosstab(df['listed_in(type)'],df['listed_in(city)']),cmap='viridis')
# Out:
# <Axes: xlabel='listed_in(city)', ylabel='listed_in(type)'>

# %% [markdown]
# #### Conclusion

# %% [markdown]
# ##### The restaurant performs equally good in all the cities. Although Birigade road,Church street and Rajnagar should be prioritised for setting up a new outlet.The buffets and night drinks are the highest rated among all the other restaurant types. So these should be prioritised.
